# %% [markdown]
# # CAPSTONE PROJECT - Certified Data Analyst

# %% [markdown]
# ## 1. Connect Colab to Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# ## 2. Import Packages

# %%
import os
import sqlite3
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Connect SQLite to Python

# %%
# Mendefinisikan path folder dimana file database disimpan
path = '/content/gdrive/MyDrive/CDA/Capstone Project [Data] - Case Study/Data/1. Coffee Shop/'

# %%
# Mengecek ada file apa saja pada path yang digunakan
os.listdir(path)
# Out:
# ['CoffeeShop_Dataset.db']

# %%
# Membuat connection ke database CoffeeShop
conn = sqlite3.connect(path + 'CoffeeShop_Dataset.db')

# Membuat cursor object untuk memanggil SQL statement
cur = conn.cursor()

# %% [markdown]
# ## 4. Data Preparation Using SQL

# %%
# Mengecek terdapat tabel apa saja di CoffeeShop_Dataset.db
cur.execute("""
              SELECT
                  name
              FROM sqlite_master
              WHERE type='table'
            """)

print(cur.fetchall())
# Out:
# [('sales outlet',), ('pastry inventory',), ('product',), ('generations',), ('sales reciepts',), ('customer',)]

# %%
# Menampilkan tabel sales outlet dalam bentuk dataframe
sales_outlet = pd.read_sql_query('SELECT * FROM "sales outlet"', conn)
sales_outlet
# Out:
#    sales_outlet_id sales_outlet_type  store_square_feet       store_address  \
# 0                2         warehouse               3400  164-14 Jamaica Ave
# 1                3            retail               1300      32-20 Broadway
# 2                4            retail               1300    604 Union Street
# 3                5            retail                900   100 Church Street
# 4                6            retail               1000      122 E Broadway
# 5                7            retail               1200   224 E 57th Street
# 6                8            retail               1500      687 9th Avenue
# 7                9            retail               1700      175 8th Avenue
# 8               10            retail               1600   183 W 10th Street
#
#          store_city store_state_province store_telephone  store_postal_code  \
# 0           Jamaica                   NY    972-871-0402              11432
# ...

# %%
# Menampilkan tabel pastry inventory dalam bentuk dataframe
pastry_inventory = pd.read_sql_query('SELECT * FROM "pastry inventory"', conn)
pastry_inventory
# Out:
#      sales_outlet_id transaction_date  product_id  start_of_day  \
# 0                  3         4/1/2019          69            18
# 1                  3         4/1/2019          70            18
# 2                  3         4/1/2019          71            18
# 3                  3         4/1/2019          72            48
# 4                  3         4/1/2019          73            18
# ..               ...              ...         ...           ...
# 302                8        4/27/2019          69            18
# 303                8        4/27/2019          70            18
# 304                8        4/27/2019          71            18
# 305                8        4/27/2019          72            48
# 306                8        4/27/2019          73            18
#
#      quantity_sold  waste % waste
# 0                8     10     56%
# 1               12      6     33%
# 2                8     10     56%
# 3                9     39     81%
# ...

# %%
# Menampilkan tabel product dalam bentuk dataframe
product = pd.read_sql_query('SELECT * FROM product', conn)
product
# Out:
#     product_id    product_group product_category       product_type  \
# 0            1  Whole Bean/Teas     Coffee beans      Organic Beans
# 1            2  Whole Bean/Teas     Coffee beans  House blend Beans
# 2            3  Whole Bean/Teas     Coffee beans     Espresso Beans
# 3            4  Whole Bean/Teas     Coffee beans     Espresso Beans
# 4            5  Whole Bean/Teas     Coffee beans      Gourmet Beans
# ..         ...              ...              ...                ...
# 83          84          Add-ons         Flavours      Regular syrup
# 84          85        Beverages           Coffee   Specialty coffee
# 85          87        Beverages           Coffee   Barista Espresso
# 86          88        Beverages           Coffee   Barista Espresso
# 87          89             Food           Bakery              Scone
#
#                        product  \
# 0          Brazilian - Organic
# 1     Our Old Time Diner Blend
# 2               Espresso Roast
# ...

# %%
# Menampilkan tabel generations dalam bentuk dataframe
generations = pd.read_sql_query('SELECT * FROM generations', conn)
generations
# Out:
#     birth_year    generation
# 0         1946  Baby Boomers
# 1         1947  Baby Boomers
# 2         1948  Baby Boomers
# 3         1949  Baby Boomers
# 4         1950  Baby Boomers
# ..         ...           ...
# 65        2011         Gen Z
# 66        2012         Gen Z
# 67        2013         Gen Z
# 68        2014         Gen Z
# 69        2015         Gen Z
#
# [70 rows x 2 columns]

# %%
# Menampilkan tabel sales reciepts dalam bentuk dataframe
sales_reciepts = pd.read_sql_query('SELECT * FROM "sales reciepts"', conn)
sales_reciepts
# Out:
#        transaction_id transaction_date transaction_time  sales_outlet_id  \
# 0                   7       2019-04-01         12:04:43                3
# 1                  11       2019-04-01         15:54:39                3
# 2                  19       2019-04-01         14:34:59                3
# 3                  32       2019-04-01         16:06:04                3
# 4                  33       2019-04-01         19:18:37                3
# ...               ...              ...              ...              ...
# 49889             753       2019-04-29         16:51:58                8
# 49890             756       2019-04-29         16:51:14                8
# 49891             759       2019-04-29         11:17:36                8
# 49892             763       2019-04-29         15:45:52                8
# 49893             763       2019-04-29         15:45:52                8
#
#        staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# ...

# %%
# Menampilkan tabel customer dalam bentuk dataframe
customer = pd.read_sql_query('SELECT * FROM customer', conn)
customer
# Out:
#       customer_id  home_store customer_first-name        customer_email  \
# 0               1           3           Kelly Key  Venus@adipiscing.edu
# 1               2           3     Clark Schroeder        Nora@fames.gov
# 2               3           3      Elvis Cardenas    Brianna@tellus.edu
# 3               4           3        Rafael Estes           Ina@non.gov
# 4               5           3          Colin Lynn      Dale@Integer.com
# ...           ...         ...                 ...                   ...
# 2241         8497           8                 Rae    Kylie@facilisi.org
# 2242         8498           8               April    Daniel@placerat.us
# 2243         8499           8          Clementine          Dieter@ac.us
# 2244         8500           8               Linda    Dillon@pretium.gov
# 2245         8501           8               Moana   Herrod@ultrices.gov
#
#      customer_since loyalty_card_number   birthdate gender  birth_year
# ...

# %% [markdown]
# query = """
# SELECT customer_since
# FROM generation as gn
# JOIN customer_since.gn
# """
#
# df = pd.read_sql_query(query, conn)
# print(df)

# %%
query = """
SELECT cs.customer_since
FROM generation as gn
JOIN customer_since as cs ON gn.id = cs.generation_id
WHERE gn.generation_name = 'Millennials'
"""

df = pd.read_sql_query(query, conn)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       1 query = """
#       2 SELECT cs.customer_since
#       3 FROM generation as gn
#       4 JOIN customer_since as cs ON gn.id = cs.generation_id
#       5 WHERE gn.generation_name = 'Millennials'
#       6 """
# ----> 8 df = pd.read_sql_query(query, conn)
#       9 print(df)
#
# NameError: name 'pd' is not defined

# %%
generasi = pd.read_sql_query('SELECT * FROM customer WHERE "customer_since" ', conn)
generasi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 generasi = pd.read_sql_query('SELECT * FROM customer WHERE "customer_since" ', conn)
#       2 generasi
#
# NameError: name 'pd' is not defined
